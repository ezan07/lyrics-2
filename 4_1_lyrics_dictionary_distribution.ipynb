# %%
#_distribution

class lyrics_dic_distribution:
        
    def __init__(self):
        
        #_[notin,in]
        #
        #_list(range(5)=[0,1,2,3,4]
        
        f1 = open(lyrics)
        f2 = f1.read()
        f1.close
        lyricssplit = f2.split(' ')
        print("16_len_lyricssplit_=",len(lyricssplit))
        list_range_len_lyricssplit = list(range(len(lyricssplit)))
        
        for i in list(range(5)):
            print("20_dictionary = ",dictionary[i])
            
            f1 = open(dictionary[i])
            f2 = f1.read()
            f1.close
            dictionarysplit[i] = f2.split(' ')
            print("26_",i,"_len_split_=",len(dictionarysplit[i]))
            
        print("28_dictionarysplit[0][0]=",dictionarysplit[0][0],dictionarysplit[0][1],dictionarysplit[0][2])
        print("29_dictionarysplit[1][0]=",dictionarysplit[1][0],dictionarysplit[1][1],dictionarysplit[1][2])
        print("30_dictionarysplit[2][0]=",dictionarysplit[2][3],dictionarysplit[2][4],dictionarysplit[2][5])
        print("31_dictionarysplit[3][0]=",dictionarysplit[3][6],dictionarysplit[3][7],dictionarysplit[3][8])
        print("32_dictionarysplit[4][0]=",dictionarysplit[4][9],dictionarysplit[4][10],dictionarysplit[4][11])
        print()
        
        c1 =[]
        c2 =[]
        
        for j in list(range(5)):
            
            for k in list_range_len_lyricssplit:
                
                if lyricssplit[k] not in dictionarysplit[j]:
                    #_print("46_",lyricssplit[k])
                    c1.append(lyricssplit[k])
                    
                else:
                    #_print("50_",lyricssplit[k])
                    c2.append(lyricssplit[k])
                    
            dicnotin[j] = c1
            print("51_dicnotin[",j,"]_len=",len(dicnotin[j]))
            #_print("49_dicnotin[",j,"]=",dicnotin[j],"\n")
            
            dicin[j] = c2
            print("55_dicin[",j,"]_len=",len(dicin[j]))
            print("56_dicin[",j,"]=",dicin[j],"\n")
            
            #_c1,c2,reset
            c1= []
            c2 = []
            #
        #_C1_in
        print("63_C1in=",dicin[0])
        print("64_len(C1in)=",len(dicin[0]))    
        #_A1add_(set_difference)
        
        A1add = set(dicin[1]) - set(dicin[0])
        print("68_A1add=",A1add)
        print("69_len(A1add)=",len(A1add))
        
        #_A2add_(set_difference)
        
        A2add = set(dicin[2]) - set(dicin[1])
        print("74_A2add=",A2add)
        print("75_len(A2add)=",len(A2add))
        
        #_B1add_(set_difference)
        
        B1add = set(dicin[3]) - set(dicin[2])
        print("80_B1add=",B1add)
        print("81_len(B1add)=",len(B1add))
        
        #_B2add_(set_difference)
        
        B2add = set(dicin[4]) - set(dicin[3])
        print("86_B2add=",B2add)
        print("87_len(B2add)=",len(B2add))
        
        #_C1A1A2B1B2_notin_word
        print("90_C1A1A2B1B2_notin_word= ",dicnotin[4])
        print("91_llen_C1A1A2B1B2_notin_word=",len(dicnotin[4]))
        
        #_lyrics_wordAB_(sum)
        
        setC1A1A2B1B2 = set(dicin[0])|A1add|A2add|B1add|B2add|set(dicnotin[4])
        print("96_len_setC1A1A2B1B2=",len(setC1A1A2B1B2))
        defferrence_L_D = len(lyricssplit)-len(setC1A1A2B1B2)
        print("98_defferrence(lyricsword-dictionaryword)=",defferrence_L_D)
        
        #
#_lyrics ----------------------------

lyrics = "imagine_join.txt"
#_lyrics = "Imagine__join.txt"
#_lyrics = "blowin in the wind_join.txt"
#_lyrics = "Blowin' in the Wind_join.txt"


#_dictionary ----------------------------

dictionary = list(range(5))
print("112_dictionary[]=",list(range(5)))    #_[0, 1, 2, 3, 4]

dictionary[0] = "C1_dictionary.txt"
print("115_dictionary[0]=",dictionary[0])
dictionary[1] = "A1_dic1086.txt"
dictionary[2] = "A1A2_dic2332.txt"
dictionary[3] = "A1A2B1_dic4463.txt"
dictionary[4] = "A1A2B1B2_dic6935.txt"

dictionarysplit = list(range(5))
print("122_dictionarysplit=",dictionarysplit[0],dictionarysplit[1])

dicnotin = list(range(5))
print("125_dicnotin=",dicnotin[0],dicnotin[1])

dicin = list(range(5))
print("128_dicin=",dicin[0],dicin[1])

#_class

wABdis = lyrics_dic_distribution()


print()
#
# Out:
# 112_dictionary[]= [0, 1, 2, 3, 4]
# 115_dictionary[0]= C1_dictionary.txt
# 122_dictionarysplit= 0 1
# 125_dicnotin= 0 1
# 128_dicin= 0 1
# 16_len_lyricssplit_= 66
# 20_dictionary =  C1_dictionary.txt
# 26_ 0 _len_split_= 13
# 20_dictionary =  A1_dic1086.txt
# 26_ 1 _len_split_= 1086
# 20_dictionary =  A1A2_dic2332.txt
# 26_ 2 _len_split_= 2332
# 20_dictionary =  A1A2B1_dic4463.txt
# 26_ 3 _len_split_= 4463
# 20_dictionary =  A1A2B1B2_dic6935.txt
# 26_ 4 _len_split_= 6935
# 28_dictionarysplit[0][0]=  - Ah
# 29_dictionarysplit[1][0]=  'm 're
# 30_dictionarysplit[2][0]= 's A.M. AM
# 31_dictionarysplit[3][0]= April Atlantic August
# 32_dictionarysplit[4][0]= CD CD-ROM CV
#
# 51_dicnotin[ 0 ]_len= 65
# 55_dicin[ 0 ]_len= 1
# 56_dicin[ 0 ]= ['']
#
# 51_dicnotin[ 1 ]_len= 12
# 55_dicin[ 1 ]_len= 54
# ...
